# %%
import pandas as pd
import os

# %%
data_path = '../../data/music_data'

# %%
music_meta = os.path.join(data_path, 'music_meta')
df_music_meta = pd.read_csv(music_meta,
                                sep='\001',
                                nrows=100,
                                names=['item_id', 'item_name', 'desc', 'total_timelen', 'location', ';tags'])

# %%
df_music_meta.head(50)
# Out:
#        item_id                                          item_name  \
# 0     93709100                        韩国少女时代最新回归新专主打《I GOT A BOY》
# 1    102209100                            韩国张力尹携手EXO成员CHEN《呼吸》中文版
# 2     29900100                                          徐颢菲《猫的借口》
# 3    368709100                                         美女翻唱 别问我是谁
# 4    603409100                                     龙梅子,老猫 老爸老爸你好吗
# 5    637909100                              《中国好歌曲》  诙?镜诹?赸-韩磊天边》
# 6    847609100                                HAO简单官网音乐基础教程唱歌伴奏软件
# 7    849109100                                   HAO乐理基础教程简单编曲教程网
# 8    850509100                                 HAO简单音乐教程音乐基础教程妮妮网
# 9    864509100                      Mike Candys  Maury - Miracles
# 10   887209100                                    Super Duper Fly
# 11   935509100                         【高清】驚喜合唱 台北101的美食街快闪街舞美聲表演
# 12   963409100                                     EXO - 十二月的奇迹-韩
# 13  1072109100                          ZIA - Have You Ever Cried
# 14  1084709100                                      outta my head
# 15  1119509100                                           GEE 少女时代
# 16  1126809100                          SPICA - You Don't Love Me
# 17  1128409100                                       宫崎骏《千与千寻》主题曲
# 18  1144209100                                  TAE MIN  -  Steps
# 19  1153109100                                           《盗马记》主题曲
# 20  1157309100                                THE SEEYA - tell me
# 21  1167409100                               A-PRINCE - Love Snow
# 22  1179809100                                         歌曲：Love UU
# 23  1203109100                   Lee Min Woo_M 'TAXI' (Feat.ERIC)
# 24  1210309100                    SHINHWA 'This Love' _DANCE VER.
# 25  1220309100             SHINHWA's 11th THE CLASSIC 'This Love'
# 26  1399509100                                  HAO简单音乐入门教程最新爱乐资讯
# 27  1415009100  S.M. THE BALLAD Vol.2 Joint Recital_(Breath)_b...
# 28  1633709100                                 宫崎骏新作《起风了》主题曲——清爽版
# 29  1712309100              8岁正太萝莉Babywockee和JuJu Beatz 街边DUBSTEP
# 30  1827609100                                         神曲狐狸叫.zero
# 31  1911809100                               AOA - 短裙 SBS人气歌谣 现场版
# 32  1918609100                    B·A·P - 1004(Angel) SBS人气歌谣 现场版
# 33  1936609100                     边伯贤&SUHO 声音模仿 SBS人气歌谣 14_02_16
# 34  1939109100               GOT7 - Girls Girls Girls SBS人气歌谣 现场版
# 35  2107609100                                   犬夜叉——[插曲]穿越时空的思念
# 36  2180009100                                   G.E.M. 鄧紫棋 - 喜歡你
# 37  2200409100                              《爸爸去哪儿》大电影主题曲 宝贝去哪儿MV
# 38   226000100                                         李宇春《我唱啦啦啦》
# 39  2381409100                                       马景涛太祖秘史[主题曲]
# 40  2595609100                           唱出爱火花 140213 SOS班级大作战第2场
# 41  2621509100                                   追梦高中1 森动救惠美受伤 医院
# 42  2667309100                          Dream High1 森动惠美合唱  maybe
# 43  2667909100                                   森动 惠美 合唱的歌 maybe
# 44   279100100                                   超人特工队、王伟美《外面的世界》
# 45   279200100                                          王伟美《你伤不起》
# 46   279500100                                      超人特工队《做你的奥特曼》
# 47   280200100                                            刘惜君《拂晓》
# 48  2844209100                U2 - 'Invisible' (RED) Edit Version
# 49  2848209100                                 再见，青春。毕业生原创音乐《毕业礼》
#
#                                                  desc  total_timelen location  \
# 0                         韩国少女时代最新回归新专主打《I GOT A BOY》            304      NaN
# 1                             韩国张力尹携手EXO成员CHEN《呼吸》中文版            274      NaN
# 2                                                 NaN            284       国内
# 3                                          美女翻唱 别问我是谁            288      NaN
# 4                                      龙梅子,老猫 老爸老爸你好吗            259      NaN
# 5                               《中国好歌曲》  诙?镜诹?赸-韩磊天边》            289      NaN
# 6                                 HAO简单官网音乐基础教程唱歌伴奏软件            107      NaN
# 7                                    HAO乐理基础教程简单编曲教程网            107      NaN
# 8                                  HAO简单音乐教程音乐基础教程妮妮网            107      NaN
# 9                                                  好听            169      NaN
# 10  2014年索契冬奥会，中国奥委会邀请本色音乐打造冬奥主题曲，旗下艺人张震岳率领MC HotD...            207      NaN
# 11                         【高清】驚喜合唱 台北101的美食街快闪街舞美聲表演            566      NaN
# 12                                           中韩双语同时在榜            273      NaN
# 13                                          强势上榜，天籁之作            270      NaN
# 14                                          周杰伦MV-范特西            227      NaN
# 15                                            舞蹈，舞蹈教学            197      NaN
# 16                                          敬请期待，先上预告            240      NaN
# 17                                       宫崎骏《千与千寻》主题曲            215      NaN
# 18                                           总理和我在OST            218      NaN
# 19                                           《盗马记》主题曲            129      NaN
# 20                                            富有剧情的MV            270      NaN
# 21                                          雪地拍摄，卖力演唱            195      NaN
# 22                                      歌曲，十分丰富，值得珍藏．            220      NaN
# 23                              Lee Min Woo Feat.ERIC            210      NaN
# 24                                            SHINHWA            220      NaN
# 25                         SHINHWA's 11th THE CLASSIC            223      NaN
# 26                                  HAO简单音乐入门教程最新爱乐资讯            107      NaN
# 27                                                S.M            272      NaN
# 28                                 宫崎骏新作《起风了》主题曲——清爽版            209      NaN
# 29              8岁正太萝莉Babywockee和JuJu Beatz 街边DUBSTEP            252      NaN
# 30                           最新 最热门的网络神曲大全集锦 持续更新中。。。            204      NaN
# 31                      AOA - 短裙 SBS人气歌谣 现场版 14_02_16            179      NaN
# 32                    B·A·P - 1004(Angel) SBS人气歌谣 现场版            207      NaN
# 33                     边伯贤&SUHO 声音模仿 SBS人气歌谣 14_02_16             39      NaN
# 34               GOT7 - Girls Girls Girls SBS人气歌谣 现场版            215      NaN
# 35                                   犬夜叉——[插曲]穿越时空的思念            143      NaN
# 36                                               再次登顶            244      NaN
# 37                                              爸爸去哪儿            200      NaN
# 38  天娱传媒旗下艺人李宇春新专辑发布至今，第二主打《对不起，只是忽然很想你》不仅四周蝉联Musi...            236       国内
# 39                                       看小马哥演绎一代咆哮教主            176      NaN
# 40                               SOS班级大作战第2场 美女野兽热辣全场           5056      NaN
# 41                          追梦高中  dream high 森动 惠美的爱情            180      NaN
# 42                           Dream High0森动惠美合唱  maybe             98      NaN
# 43                                        森动 惠美 maybe             98      NaN
# 44                                                NaN            624       国内
# 45                                                NaN            275       国内
# 46                                                NaN            172       国内
# 47                                                NaN            285       国内
# 48      Download here: http://smarturl.it/U2Invisible            251      NaN
# 49                                 再见，青春。毕业生原创音乐《毕业礼》            282      NaN
#
#                                              ;tags
# 0      少女时代,鹿晗,韩国,exo综艺,最新回归,exo快乐大本营,吴世勋,fx组合,音悦台
# 1          CHEN,少女时代,呼吸,鹿晗,张力尹,韩国,EXO成员,EXO,宋茜,音悦台
# 2                                              NaN
# 3                            流行歌曲,翻唱,网络歌曲,美女,舞曲,社会
# 4                                  你好吗,龙梅子,老猫,老爸老爸
# 5                        中国好歌曲,霍尊,中国好声音,火爆,我是歌手,流行
# 6                     乐理基础教程,音乐入门教程,音乐教程,音乐基础教程,流行
# 7                        乐理基础教程,音乐入门教程,音乐教程,音乐基础教程
# 8                     乐理基础教程,音乐入门教程,音乐教程,音乐基础教程,流行
# 9                                      Mike Candys
# 10  姚中仁,冬奥会,嘻哈组合,顽童,Hotdog,MJ116,冬奥主题曲,张震岳,MC,冰雪运动
# 11                                            快闪街舞
# 12                                        绝对主打歌,流行
# 13                                            天籁之音
# 14                                           周杰伦MV
# 15                                      舞蹈，舞蹈教学,流行
# 16                                          他不爱我预告
# 17                                            千与千寻
# 18                                      东方神起TAE,流行
# 19                                             盗马记
# 20                                            最新上传
# 21                                            新歌上榜
# 22                                              音乐
# 23                                            TAXI
# 24                                    This Love,流行
# 25                                       This Love
# 26                    乐理基础教程,音乐入门教程,音乐教程,音乐基础教程,流行
# 27                                              音乐
# 28                                         宫崎骏,起风了
# 29       8岁正太萝莉,Beatz,Babywockee,舞蹈,JuJu,街边DUBSTEP
# 30                        神曲集锦,热门神曲,网络神曲,神曲大全,最新神曲
# 31                                     短裙,AOA,人气歌谣
# 32                                   音乐,人气歌谣,B·A·P
# 33                                      音乐,人气歌谣,流行
# 34                        Girls Girls Gi,人气歌谣,GOT7
# 35                                             犬夜叉
# 36                                              流行
# 37                                             NaN
# 38                                             NaN
# 39                                             NaN
# 40                                           唱出爱火花
# 41                          裴秀智,追梦高中金秀贤,dreamhigh1
# 42                                 裴秀智,追梦高中,金秀贤,流行
# 43                                  裴秀智,追梦高中金秀贤,流行
# 44                                             NaN
# 45                                             NaN
# 46                                             NaN
# 47                                             NaN
# 48                                 民谣,Invisible,U2
# 49                                              原创

# %%
user_profile_info = os.path.join(data_path, 'user_profile.data')
df_user_profile = pd.read_csv(user_profile_info,
                       sep=',',
                       nrows=100,
                       names=['user_id', 'gender', 'age', 'salart', 'province'])

# %%
df_user_profile.head()
# Out:
#                             user_id gender     age        salart province
# 0  00ea9a2fe9c6810aab440c4d8c050000      女   26-35  20000-100000       江苏
# 1  01a0ae50fd4b9ef6ed04c22a7e421000      女   36-45        0-2000       河北
# 2  002db7d2360562dd16828c4b91402000      女  46-100    5000-10000       云南
# 3  006a184749e3b3eb83e9eb516d522000      男   36-45     2000-5000       天津
# 4  00de61c1d635ad964eef2aefa8292000      女   19-25     2000-5000      内蒙古

# %%
user_watch_pref = os.path.join(data_path, 'user_watch_pref.sml')
df_user_watch_pref = pd.read_csv(user_watch_pref,
                       sep='\001',
                       nrows=None,
                       names=['user_id', 'item_id', 'stay_seconds', 'hour'])

# %%
df_user_watch_pref.head()
# Out:
#                             user_id     item_id  stay_seconds  hour
# 0  01e069ed67600f1914e64c0fe7730944  4090309101            15    19
# 1  01d86fc1401b283d5828c293be290e08  6192809101            75    12
# 2  002f4b9c49be9a0b2c13e1c3c4f6a21c  8915109101           385    18
# 3  01e3fdf415107cd6046a07481fbed499  6470209102          1635    21
# 4  01e3fdf415107cd6046a07481fbed499  6470209102           555    16

# %%
df_music_meta = df_music_meta.fillna('-')

# %%
df_music_meta.head()
# Out:
#      item_id                    item_name                         desc  \
# 0   93709100  韩国少女时代最新回归新专主打《I GOT A BOY》  韩国少女时代最新回归新专主打《I GOT A BOY》
# 1  102209100      韩国张力尹携手EXO成员CHEN《呼吸》中文版      韩国张力尹携手EXO成员CHEN《呼吸》中文版
# 2   29900100                    徐颢菲《猫的借口》                            -
# 3  368709100                   美女翻唱 别问我是谁                   美女翻唱 别问我是谁
# 4  603409100               龙梅子,老猫 老爸老爸你好吗               龙梅子,老猫 老爸老爸你好吗
#
#    total_timelen location                                        ;tags
# 0            304        -  少女时代,鹿晗,韩国,exo综艺,最新回归,exo快乐大本营,吴世勋,fx组合,音悦台
# 1            274        -      CHEN,少女时代,呼吸,鹿晗,张力尹,韩国,EXO成员,EXO,宋茜,音悦台
# 2            284       国内                                            -
# 3            288        -                        流行歌曲,翻唱,网络歌曲,美女,舞曲,社会
# 4            259        -                              你好吗,龙梅子,老猫,老爸老爸

# %%
del df_music_meta['desc']

# %%
df_music_meta.head()
# Out:
#      item_id                    item_name  total_timelen location  \
# 0   93709100  韩国少女时代最新回归新专主打《I GOT A BOY》            304        -
# 1  102209100      韩国张力尹携手EXO成员CHEN《呼吸》中文版            274        -
# 2   29900100                    徐颢菲《猫的借口》            284       国内
# 3  368709100                   美女翻唱 别问我是谁            288        -
# 4  603409100               龙梅子,老猫 老爸老爸你好吗            259        -
#
#                                          ;tags
# 0  少女时代,鹿晗,韩国,exo综艺,最新回归,exo快乐大本营,吴世勋,fx组合,音悦台
# 1      CHEN,少女时代,呼吸,鹿晗,张力尹,韩国,EXO成员,EXO,宋茜,音悦台
# 2                                            -
# 3                        流行歌曲,翻唱,网络歌曲,美女,舞曲,社会
# 4                              你好吗,龙梅子,老猫,老爸老爸

# %%
df_cnt = df_user_watch_pref.groupby(['user_id','item_id'])['stay_seconds'].count().reset_index()
df_cnt.columns=['user_id','item_id','count']
df_cnt.sort_values('count',ascending=False).head() #降序
# Out:
#                                  user_id    item_id  count
# 113568  00e5b556c5fda7a1b247bd78d69595fa  673600354   3922
# 226458  01c692ac26d813dba9607a7f96b7e415   68800255    313
# 223924  01c17beaefa995baf12433acbda093cc  945800328    239
# 59783   00775f1bad5eba86ed5631645adb7212  130400221    233
# 30433   003b69052af5d0d5aba2579805bb5172  910600254    229
